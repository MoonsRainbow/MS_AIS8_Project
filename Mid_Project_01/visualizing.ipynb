# %%
import numpy as np
import pandas as pd
from glob import glob
import koreanize_matplotlib
from matplotlib import ticker
import matplotlib.pyplot as plt

# %%
plt.ioff()

# %%
path_kb, path_sh, path_wr, path_jb, path_add_jb, path_kk, path_add_kk = sorted(glob('./merge_data/*.xls'))

# %%
path_kb, path_sh, path_jb, path_wr, path_kk, path_add_kk, path_add_jb
# Out:
# ('./merge_data/국민_pre_all.xls',
#  './merge_data/신한_pre_all.xls',
#  './merge_data/전북_pre_all.xls',
#  './merge_data/우리_pre_all.xls',
#  './merge_data/카카오_pre_all.xls',
#  './merge_data/카카오_고정이하여신비율.xls',
#  './merge_data/전북_고정이하여신비율.xls')

# %%
df_kb = pd.read_excel(path_kb)
df_sh = pd.read_excel(path_sh)
df_jb = pd.read_excel(path_jb)
df_wr = pd.read_excel(path_wr)
df_kk = pd.read_excel(path_kk)
df_add_kk = pd.read_excel(path_add_kk)
df_add_jb = pd.read_excel(path_add_jb)

# %%
df_kb
# Out:
#            0  총대출채권_연체율  기업대출_연체율  기업대출_대기업대출_연체율  기업대출_중소기업대출_연체율  \
# 0   2017년03월       0.36      0.48            0.80             0.42
# 1   2017년06월       0.30      0.36            0.27             0.38
# 2   2017년09월       0.28      0.34            0.28             0.34
# 3   2017년12월       0.23      0.23            0.31             0.22
# 4   2018년03월       0.27      0.31            0.30             0.31
# 5   2018년06월       0.25      0.25            0.30             0.24
# 6   2018년09월       0.26      0.26            0.04             0.30
# 7   2018년12월       0.24      0.23            0.02             0.26
# 8   2019년03월       0.28      0.27            0.04             0.31
# 9   2019년06월       0.28      0.25            0.02             0.29
# 10  2019년09월       0.30      0.28            0.07             0.31
# 11  2019년12월       0.25      0.21            0.00             0.24
# 12  2020년03월       0.25      0.20            0.01             0.24
# ...

# %%
df_sh
# Out:
#    연도 및 분기 별  유동성커버리지비율  순안정자금조달비율   기업여신:총여신  기업여신_대기업:총여신  기업여신_중소기업:총여신  \
# 0   2017년03월     110.09        NaN  110753354      33689278       77064074
# 1   2017년06월     105.84        NaN  112858302      33752591       79105710
# 2   2017년09월      95.78        NaN  117342998      35060721       82282277
# 3   2017년12월      93.75        NaN  117109958      33489034       83620924
# 4   2018년03월      99.76     114.01  116705177      31906268       84798907
# 5   2018년06월      99.12     111.17  122414011      35028255       87385755
# 6   2018년09월      97.20     111.21  125112551      36006754       89105798
# 7   2018년12월      97.68     112.57  126274466      35914012       90360457
# 8   2019년03월     103.44     111.12  129166450      36028257       93138193
# 9   2019년06월     103.24     109.23  132409143      36773173       95635969
# 10  2019년09월     103.40     107.73  132778288      36434798       96343490
# ...

# %%
df_wr
# Out:
#    Unnamed: 0  고정이하여신비율  순고정이하여신비율  대손충당금적립잔액  대손충당금적립비율(총여신대비)  \
# 0    2017년03월      0.85       0.44    1588261              0.74
# 1    2017년06월      0.82       0.43    1511171              0.70
# 2    2017년09월      0.73       0.37    1539715              0.70
# 3    2017년12월      0.83       0.37    1613533              0.73
# 4    2018년03월      0.79       0.35    1771198              0.79
# 5    2018년06월      0.51       0.29    1398723              0.62
# 6    2018년09월      0.46       0.28    1332963              0.58
# 7    2018년12월      0.51       0.27    1409628              0.60
# 8    2019년03월      0.47       0.25    1319592              0.56
# 9    2019년06월      0.43       0.25    1236581              0.51
# 10   2019년09월      0.41       0.23    1267901              0.51
# 11   2019년12월      0.40       0.23    1193341              0.49
# 12   2020년03월      0.40       0.23    1205043              0.48
# 13   2020년06월      0.38       0.22    1329438              0.52
# ...

# %%
df_jb
# Out:
#            0  총 기업대출금  기업대출금_건설업  기업대출금_부동산및임대업  기업여신:고정이하여신  기업여신_대기업:고정이하여신  \
# 0   2017년03월  6944640     526076        2635121       115811             9833
# 1   2017년06월  6947505     526721        2737785       110552             9834
# 2   2017년09월  6911679     523254        2762974        93609             9833
# 3   2017년12월  6952426     484247        2858811        95324             9833
# 4   2018년03월  7057963     485172        3013340        91132             9833
# 5   2018년06월  6993222     451860        3092307        95088             9827
# 6   2018년09월  6989807     437463        3117922        94264             9821
# 7   2018년12월  6943161     403628        3148809        79698             9093
# 8   2019년03월  7055407     469179        3141909        78193             9093
# 9   2019년06월  7084044     497648        3167459        61937             9093
# 10  2019년09월  7107441     509443        3183487        61002             9093
# ...

# %%
df_kk
# Out:
#            0  유동성커버리지비율  순안정자금조달비율  총대출채권_연체율  기업대출_대기업대출_연체율  \
# 0   2017년03월        NaN        NaN        NaN             NaN
# 1   2017년06월        NaN        NaN        NaN             NaN
# 2   2017년09월     250.33        NaN       0.00             0.0
# 3   2017년12월     154.75        NaN       0.01             0.0
# 4   2018년03월     279.51        NaN       0.03             0.0
# 5   2018년06월     520.26        NaN       0.06             0.0
# 6   2018년09월     406.62        NaN       0.13             0.0
# 7   2018년12월     307.77        NaN       0.12             0.0
# 8   2019년03월     467.99        NaN       0.16             0.0
# 9   2019년06월     612.07        NaN       0.17             0.0
# 10  2019년09월     692.95        NaN       0.19             0.0
# 11  2019년12월     696.57        NaN       0.20             0.0
# 12  2020년03월     623.41     207.68       0.20             0.0
# 13  2020년06월     713.03     193.72       0.22             0.0
# ...

# %%
df = pd.read_csv('./data/pre_all_201703-202309.csv')
df
# Out:
#    Unnamed: 0  총대출채권_연체율  기업대출_연체율  기업대출_대기업대출_연체율  기업대출_중소기업대출_연체율  \
# 0    2017년03월       0.36      0.48            0.80             0.42
# 1    2017년06월       0.30      0.36            0.27             0.38
# 2    2017년09월       0.28      0.34            0.28             0.34
# 3    2017년12월       0.23      0.23            0.31             0.22
# 4    2018년03월       0.27      0.31            0.30             0.31
# 5    2018년06월       0.25      0.25            0.30             0.24
# 6    2018년09월       0.26      0.26            0.04             0.30
# 7    2018년12월       0.24      0.23            0.02             0.26
# 8    2019년03월       0.28      0.27            0.04             0.31
# 9    2019년06월       0.28      0.25            0.02             0.29
# 10   2019년09월       0.30      0.28            0.07             0.31
# 11   2019년12월       0.25      0.21            0.00             0.24
# 12   2020년03월       0.25      0.20            0.01             0.24
# ...

# %% [markdown]
# ## LCR

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['유동성커버리지비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['유동성커버리지비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['유동성커버리지비율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['유동성커버리지비율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axhline(100, color='g', ls='--')
plt.text(13.8, 101.0, 'LCR 안정권', fontsize='large')
plt.title('은행 별 LCR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('LCR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['유동성커버리지비율'][8:], color='#ffbc0130')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['유동성커버리지비율'][8:], color='#0046ff30')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['유동성커버리지비율'][8:], color='#20c4f430')
axes.plot(df_jb['0'][8:], df_jb['유동성커버리지비율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axhline(100, color='g', ls='--')
plt.text(13.8, 101.0, 'LCR 안정권', fontsize='large')
plt.title('은행 별 LCR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('LCR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['유동성커버리지비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['유동성커버리지비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['유동성커버리지비율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['유동성커버리지비율'][8:], color='#012d6c10')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axhline(100, color='g', ls='--')
plt.text(13.8, 101.0, 'LCR 안정권', fontsize='large')
plt.title('은행 별 LCR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('LCR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kk['0'][8:], df_kk['유동성커버리지비율'][8:], color='#291e21')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axvline(10, color='red', ls='--')
plt.title('카카오뱅크 LCR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('LCR (%)', fontsize=16, labelpad=24)
plt.text(9.0, 1050.0, '상장 전 ←', fontsize='large')
plt.text(10.25, 1050.0, '→ 상장 후', fontsize='large')
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %% [markdown]
# ## 고정이하여신비율

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['고정이하여신비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['고정이하여신비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['고정이하여신비율'][8:], color='#20c4f4')
axes.plot(df_add_jb.iloc[:, 7:].T[0][8:], df_add_jb.iloc[:, 7:].T[1][8:], color='#012d6c')
axes.plot(df_add_kk.iloc[:, 7:].T[0][8:], df_add_kk.iloc[:, 7:].T[1][8:], color='#291e21')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axvline(10, color='red', ls='--')
plt.text(8.2, 0.72, '카카오뱅크 상장 전 ←', fontsize='large')
plt.text(10.25, 0.72, '→ 카카오뱅크 상장 후', fontsize='large')
plt.title('은행 별 고정이하여신비율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행', '카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=5)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('고정이하여신비율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['고정이하여신비율'][8:], color='#ffbc0130')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['고정이하여신비율'][8:], color='#0046ff30')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['고정이하여신비율'][8:], color='#20c4f430')
axes.plot(df_add_jb.iloc[:, 7:].T[0][8:], df_add_jb.iloc[:, 7:].T[1][8:], color='#012d6c')
axes.plot(df_add_kk.iloc[:, 7:].T[0][8:], df_add_kk.iloc[:, 7:].T[1][8:], color='#291e2130')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 고정이하여신비율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행', '카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=5)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('고정이하여신비율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['고정이하여신비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['고정이하여신비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['고정이하여신비율'][8:], color='#20c4f4')
axes.plot(df_add_jb.iloc[:, 7:].T[0][8:], df_add_jb.iloc[:, 7:].T[1][8:], color='#012d6c10')
axes.plot(df_add_kk.iloc[:, 7:].T[0][8:], df_add_kk.iloc[:, 7:].T[1][8:], color='#291e21')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axvline(10, color='red', ls='--')
plt.text(8.2, 0.72, '카카오뱅크 상장 전 ←', fontsize='large')
plt.text(10.25, 0.72, '→ 카카오뱅크 상장 후', fontsize='large')
plt.title('은행 별 고정이하여신비율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행', '카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=5)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('고정이하여신비율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %% [markdown]
# ## NSFR

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['순안정자금조달비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['순안정자금조달비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['순안정자금조달비율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['순안정자금조달비율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 NSFR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('NSFR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['순안정자금조달비율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['순안정자금조달비율'][8:], color='#0046ff30')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['순안정자금조달비율'][8:], color='#20c4f430')
axes.plot(df_jb['0'][8:], df_jb['순안정자금조달비율'][8:], color='#012d6c10')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 NSFR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('NSFR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['순안정자금조달비율'][8:], color='#ffbc0130')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['순안정자금조달비율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['순안정자금조달비율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['순안정자금조달비율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 NSFR (%)', fontsize=24, pad=36, loc='left')
axe_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('NSFR (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kk['0'][12:], df_kk['순안정자금조달비율'][12:], color='#291e21')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axvline(6, color='red', ls='--')
plt.title('카카오뱅크 NSFR (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('NSFR (%)', fontsize=16, labelpad=24)
plt.text(5.25, 206.0, '상장 전 ←', fontsize='large')
plt.text(6.25, 206.0, '→ 상장 후', fontsize='large')
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][12:])[::2])
plt.show()

# %% [markdown]
# ## 대손충당금

# %%
df_add2_kk = pd.read_excel('./origin_data/all_201703-202209.xls', header=1)

# %%
df_add2_kk = df_add2_kk.loc[df_add2_kk['회사명'] == '주식회사 카카오뱅크']
df_add2_kk = df_add2_kk[df_add2_kk['항목'] == '대손충당금적립비율(고정이하여신대비)']

# %%
df_add2_kk = df_add2_kk.T.iloc[7:].reset_index(names='연월')

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['대손충당금적립비율(고정이하여신대비)'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['대손충당금적립비율(고정이하여신대비)_y'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['대손충당금적립비율(고정이하여신대비)'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['대손충당금적립비율(고정이하여신대비)'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axhline(100, color='g', ls='--')
plt.text(12.7, 106.0, '대손충당금적립비율 안정권', fontsize='large')
plt.title('은행 별 대손충당금적립비율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('대손충당금적립비율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_add2_kk['연월'][8:], df_add2_kk[39][8:], color='#291e21')
axes.spines[['right', 'top', 'left']].set_visible(False)
axes.axvline(10, color='red', ls='--')
plt.title('카카오뱅크 대손충당금적립비율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['카카오뱅크'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('대손충당금적립비율 (%)', fontsize=16, labelpad=24)
plt.text(9.05, 272.0, '상장 전 ←', fontsize='large')
plt.text(10.25, 272.0, '→ 상장 후', fontsize='large')
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %% [markdown]
# ## 연체율

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['기업대출_연체율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['기업대출_연체율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['기업대출_연체율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['기업대출_연체율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 기업대출 연체율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('기업대출 연체율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['기업대출_연체율'][8:], color='#ffbc0130')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['기업대출_연체율'][8:], color='#0046ff30')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['기업대출_연체율'][8:], color='#20c4f430')
axes.plot(df_jb['0'][8:], df_jb['기업대출_연체율'][8:], color='#012d6c')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 기업대출 연체율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('기업대출 연체율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()

# %%
figure, axes = plt.subplots(figsize=[20, 6])
axes.plot(df_kb['0'][8:], df_kb['기업대출_연체율'][8:], color='#ffbc01')
axes.plot(df_sh['연도 및 분기 별'][8:], df_sh['기업대출_연체율'][8:], color='#0046ff')
axes.plot(df_wr['Unnamed: 0'][8:], df_wr['기업대출_연체율'][8:], color='#20c4f4')
axes.plot(df_jb['0'][8:], df_jb['기업대출_연체율'][8:], color='#012d6c10')
axes.spines[['right', 'top', 'left']].set_visible(False)
plt.title('은행 별 기업대출 연체율 (%)', fontsize=24, pad=36, loc='left')
axes_legend = plt.legend(['국민은행', '신한은행', '우리은행', '전북은행'], loc='lower right', bbox_to_anchor=(1.0, 1.1), ncol=4)
axes_legend.get_frame().set_linewidth(0)
plt.xlabel('분기 (연월)', fontsize=16, labelpad=24)
plt.ylabel('기업대출 연체율 (%)', fontsize=16, labelpad=24)
plt.grid(axis='y')
plt.xticks(list(df_kb['0'][8:])[::2])
plt.show()
